# %% [markdown]
# # INTRODUCTION TO DATA ANALYSIS

# %% [markdown]
# ## *What is pandas?*
#
# - Powerful toolkit for analyzing structured data
#
# - Built ontop of NumPy
#
# - Provides specialized types, methods and functions for data analysis, offering excellent support for taasks related to data analysis and mining.
#
# ![images.jpeg](data:image/jpeg;base64,...)

# %%
import pandas as pd

df = pd.read_csv(csv, sep=",")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ## Why Pandas?
#
# - **Data Cleaning and Preparation:** Functions for merging, joining, and concatenating data.
# Powerful data cleaning techniques like removing duplicates, replacing values, and filtering data.
#
# - **Data Transformation:** Reshaping and pivoting of datasets.
# Label-based slicing, fancy indexing, and subsetting of large datasets.
#
# - **Grouping and Aggregation:** Splitting data into groups based on some criteria and applying functions to each group independently (group by).
#
# - **Efficiency:** Efficient storage and data alignment. Fast operations and computations on large datasets.
#
# - ***Pandas does what SQL can in one line.***

# %%
df.to_sql('pokemon', conn, index=False, if_exists='replace')

# Which on average has the highest attack Fire , Water or Grass
sql_query = """
SELECT `Type 1`, AVG(`Attack`) as AverageAttack
FROM pokemon
WHERE `Type 1` == "Fire" OR `Type 1` == "Water" OR `Type 1` == "Grass"
GROUP BY `Type 1`;
"""

# Execute the query and fetch the results
average_attack_sql = pd.read_sql_query(sql_query, conn)
average_attack_sql
# Out:
#   Type 1  AverageAttack
# 0   Fire      84.769231
# 1  Grass      73.214286
# 2  Water      74.151786

# %%
# Which on average has the highest attack Fire , Water or Grass
average_attack_by_type = df.groupby('Type 1')['Attack'].mean()
average_attack_by_type[['Fire','Water','Grass']]
# Out:
# Type 1
# Fire     84.769231
# Water    74.151786
# Grass    73.214286
# Name: Attack, dtype: float64

# %% [markdown]
# # **I/O Reading & Writing Data**
#
# ## *Reading Data*
#
# - read CSV : pandas converts comma seperated files into a dataframe.
#
# - read JSON : pandas converts Javascript Object Notation into a dataframe.
#
# - read excel : allows you to convert excel files (i.e xml , xls)
#
# - read HTML : read html tables (increadibly useful if you're scraping websites in tandem with something like Beautiful Soup)
#
# ```python
# import numpy as np
# df.read_csv("path/to/file.csv")
#
# ```

# %% [markdown]
# ## *Output Data*
#
# Pandas allows exporting data to a variety of file formats, making it easy to share or store data externally. Common formats include:
#
# - **CSV:** you can set certain parameters. For instance you can use tabs as delimiters.
# - **Excel:** exports data to an Excel file, useful for compatibility with spreadsheet software.
# - **JSON:** exports data to a JSON file, often used in web applications and for data interchange.
# - **HTML:** exports data to an HTML table, which can be useful for web reporting.
# - **SQL:** Pandas can write directly to SQL.

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>#</th>\n      <th>Name</th>\n      <th>Type 1</th>\n      <th>Type 2</th>\n      <th>Total</th>\n      <th>HP</th>\n      <th>Attack</th>\n      <th>Defense</th>\n      <th>Sp. Atk</th>\n      <th>Sp. Def</th>\n      <th>Speed</th>\n      <th>Generation</th>\n      <th>Legendary</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>Bulbasaur</td>\n      <td>Grass</td>\n      <td>Poison</td>\n      <td>318</td>\n      <td>45</td>\n      <td>49</td>\n      <td>49</td>\n      <td>65</td>\n      <td>65</td>\n      <td>45</td>\n      <td>1</td>\n      <td>False</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>
series2 = pd.Series(fav_pokemon, index=fav_pokemon_idx)
series2

# Note the ordered nature can still be accessed using index
# series2.iloc[2] == series2[658]
# Out:
# 384    Greninja
# 448     Lucario
# 658    Rayquaza
# dtype: object

# %%
fav_pokemon_dict = dict(zip(fav_pokemon_idx,fav_pokemon))

print(fav_pokemon_dict)
series3 = pd.Series(fav_pokemon_dict)
series3
# Out:
# {384: 'Greninja', 448: 'Lucario', 658: 'Rayquaza'}
# 384    Greninja
# 448     Lucario
# 658    Rayquaza
# dtype: object

# %% [markdown]
# - applying a function to an entire series of data
#
# ![image.png](data:image/png;base64,...)

# %%
def hp_calc(base,IV=31,EV=252,level=100):
  return  ((2 * base + IV + (EV//4)) * level)//100 + level + 10

max_hp = df["HP"].apply(hp_calc)
max_hp
# Out:
# 0      294
# 1      324
# 2      364
# 3      364
# 4      282
#       ...
# 795    304
# 796    304
# 797    364
# 798    364
# 799    364
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# Q1. Find the lowest possible HP a pokemon can potentially have. Make a list of tuples of (min_HP , max_highest) for each pokemon.
#
# Hints :
#   - Feel free to use ```hp_calc``` or implement the equation yourself
#   - Note ```IV``` and ```EV``` should both be set to ```0```
#   - ```level``` REMAINS ```100```
#
# Example Output:
#
# The output should be a list of tuples, each representing the minimum and maximum HP of a Pokémon:
#
# ```[(min_hp_1, max_hp_1), (min_hp_2, max_hp_2), ...]```

# %%
min_hp = df["HP"].apply(lambda x : hp_calc(base = x,IV=0,EV=0,level=100)) # note the use of a lambda function/ annoynmous functions
# min_hp = df["HP"].apply(lambda x : ((2 * x) * 100)//100 + 100 + 10)
print(list(zip(min_hp,max_hp)))
# Out:
# [(200, 294), (230, 324), (270, 364), (270, 364), (188, 282), (226, 320), (266, 360), (266, 360), (266, 360), (198, 292), (228, 322), (268, 362), (268, 362), (200, 294), (210, 304), (230, 324), (190, 284), (200, 294), (240, 334), (240, 334), (190, 284), (236, 330), (276, 370), (276, 370), (170, 264), (220, 314), (190, 284), (240, 334), (180, 274), (230, 324), (180, 274), (230, 324), (210, 304), (260, 354), (220, 314), (250, 344), (290, 384), (202, 296), (232, 326), (272, 366), (250, 344), (300, 394), (186, 280), (256, 350), (340, 434), (390, 484), (190, 284), (260, 354), (200, 294), (230, 324), (260, 354), (180, 274), (230, 324), (230, 324), (250, 344), (130, 224), (180, 274), (190, 284), (240, 334), (210, 304), (270, 364), (190, 284), (240, 334), (220, 314), (290, 384), (190, 284), (240, 334), (290, 384), (160, 254), (190, 284), (220, 314), (220, 314), (250, 344), (270, 364), (290, 384), (210, 304), (240, 334), (270, 364), (190, 284), (270, 364), (190, 284), (220, 314), (270, 364), (210, 304), (240, 334), (290, 384), (300, 394), (300, 394), (160, 254), (210, 304), (214, 308), (180, 274), (230, 324), (240, 334), (290, 384), (270, 364), (320, 414), (170, 264), (210, 304), (170, 264), (200, 294), (230, 324), (230, 324), (180, 274), (230, 324), (280, 374), (170, 264), (220, 314), (190, 284), (230, 324), (230, 324), (300, 394), (210, 304), (230, 324), (210, 304), (210, 304), (290, 384), (190, 284), (240, 334
.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.select_dtypes('int')
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
# [800 rows x 9 columns]

# %% [markdown]
# # **Dataframe**
#
# - **DataFrame:** A two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It's like a spreadsheet or SQL table.
#
#   - Each column in a Dataframe is effectively a Series

# %%
import pandas as pd # pd is easier to write than pandas
import numpy as np

data = {
    'index' : fav_pokemon_dict.keys(),
    'name' : fav_pokemon_dict.values()
}

df_example = pd.DataFrame(data)
df_example = df_example.set_index("index")
df_example.head()
# Out:
#            name
# index
# 384    Greninja
# 448     Lucario
# 658    Rayquaza

# %%
print(type(df_example["name"]))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## *Viewing and Understanding Dataframes*

# %% [markdown]
# - **Head:** prints out the first 5 records

# %%
## display all rows
pd.set_option('display.max_columns', 20) # can be set to None
pd.set_option('display.max_rows', 20)
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 14  11                    Metapod    Bug     NaN    205  50      20       55
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 16  13                     Weedle    Bug  Poison    195  40      35       30
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
# 18  15                   Beedrill    Bug  Poison    395  65      90       40
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# 15       90       80     70           1      False
# 16       20       20     50           1      False
# 17       25       25     35           1      False
# 18       45       80     75           1      False
# 19       15       80    145           1      False

# %% [markdown]
# - **Tail:** prints out the last 5 records

# %%
# tails prints out the last 5
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# - **sample:** prints out a random sample of rows/records

# %%
df.sample(5)
# Out:
#        #                   Name  Type 1   Type 2  Total  HP  Attack  Defense  \
# 234  216              Teddiursa  Normal      NaN    330  60      80       50
# 246  228               Houndour    Dark     Fire    330  45      60       30
# 10     8              Wartortle   Water      NaN    405  59      63       80
# 110  102              Exeggcute   Grass  Psychic    325  60      40       80
# 3      3  VenusaurMega Venusaur   Grass   Poison    625  80     100      123
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 234       50       50     40           2      False
# 246       80       50     65           2      False
# 10        65       80     58           1      False
# 110       60       45     40           1      False
# 3        122      120     80           1      False

# %% [markdown]
# - **columns:** lists all of the columns

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# - **summary:** gives a summary of the data

# %%
df.info()
#df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# - **describe:** gives a run down of some basic statistics

# %%
df.describe()
# df.iloc[df["HP"].idxmax()] # which pokemon has the highest base HP stat
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# - **shape:** returns a tuple with the number of columns against the number of rows.

# %%
df.shape , len(df)
# Out:
# ((800, 13), 800)

# %% [markdown]
# - **Is Null:** shows the number of NaN/Null data for each column

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# - *Number of Unique:* returns the number data

# %%
df.nunique()
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         18
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %% [markdown]
# - **Sorting of Columns:** Allows you to sort Data

# %%
df.sort_values(by="Total",ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 13    10               Caterpie      Bug       NaN    195   45      30
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      100      180      100    115           3       True
# 164       70      194      120    140           1       True
# 163      100      154      100    130           1       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True
# ..       ...      ...      ...    ...         ...        ...
# 13        35       20       20     45           1      False
# 288       35       20       30     20           3      False
# 446       41       25       41     25           4      False
# 322       40       20       40     20           3      False
# 206       30       30       30     30           2      False
#
# [800 rows x 13 columns]

# %% [markdown]
# ## **Setting Index**
#
# - pd.set_index("column_name") would use the given column as the new index
#
# - This is assuming that df["column_name"] is unique.

# %%
df = df.set_index("Name")

# %% [markdown]
# # **Selecting and Extracting Data**
#
#
# - **Accessing Columns:** You can use square brackets to access any column. Additionally you can also slice columns or send in a list of column names.

# %%
# pd.set_option('display.max_rows', None)
df["Attack"]
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Charmander                52
#                         ...
# Diancie                  100
# DiancieMega Diancie      160
# HoopaHoopa Confined      110
# HoopaHoopa Unbound       160
# Volcanion                110
# Name: Attack, Length: 800, dtype: int64

# %% [markdown]
# - **Accessing List of Columns:** Additionally you can also slice columns or send in a list of column names.

# %%
df[['Attack','Defense','HP']]
# Out:
#                        Attack  Defense  HP
# Name
# Bulbasaur                  49       49  45
# Ivysaur                    62       63  60
# Venusaur                   82       83  80
# VenusaurMega Venusaur     100      123  80
# Charmander                 52       43  39
# ...                       ...      ...  ..
# Diancie                   100      150  50
# DiancieMega Diancie       160      110  50
# HoopaHoopa Confined       110       60  80
# HoopaHoopa Unbound        160       60  80
# Volcanion                 110      120  80
#
# [800 rows x 3 columns]

# %%
df[df.columns[6:]]
# Out:
#                        Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   49       65       65     45           1      False
# Ivysaur                     63       80       80     60           1      False
# Venusaur                    83      100      100     80           1      False
# VenusaurMega Venusaur      123      122      120     80           1      False
# Charmander                  43       60       50     65           1      False
# ...                        ...      ...      ...    ...         ...        ...
# Diancie                    150      100      150     50           6       True
# DiancieMega Diancie        110      160      110    110           6       True
# HoopaHoopa Confined         60      150      130     70           6       True
# HoopaHoopa Unbound          60      170      130     80           6       True
# Volcanion                  120      130       90     70           6       True
#
# [800 rows x 6 columns]

# %% [markdown]
# - **Conditional Slicing:**

# %%
df[df["Attack"] > 50]
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# Charmeleon               5     Fire     NaN    405  58      64       58
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Ivysaur                     80       80     60           1      False
# Venusaur                   100      100     80           1      False
# VenusaurMega Venusaur      122      120     80           1      False
# Charmander                  60       50     65           1      False
# Charmeleon                  80       65     80           1      False
# ...                        ...      ...    ...         ...        ...
# Diancie                    100      150     50           6       True
# DiancieMega Diancie        160      110    110           6       True
# HoopaHoopa Confined        150      130     70           6       True
# HoopaHoopa Unbound         170      130     80           6       True
# Volcanion                  130       90     70           6       True
#
# [630 rows x 12 columns]

# %% [markdown]
# Q2. Extract Special Attack and Defense Stats from Pokémon Dataset
#
# - Objective:
#   - Create a new DataFrame from an existing Pokémon dataset, containing only the columns for Special Attack (Sp. Atk) and Special Defense (Sp. Def).
#
# - Expected Output:
#   - special_stats_df should be a DataFrame containing only the Sp. Atk and Sp. Def columns.

# %%
special_stats_df = df[[c for c in df.columns if "Sp." in c]] # special stats only
# df[["Name","HP"]]

# %% [markdown]
# - **Accessing Rows:** You can use square brackets to access any rows. Additionally you can also slice.

# %%
df[df["#"] == 420]
# Out:
#            # Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Cherubi  420  Grass    NaN    275  45      35       45       62       53
#
#          Speed  Generation  Legendary
# Name
# Cherubi     35           4      False

# %% [markdown]
# ## *Loc and ILoc Function*
#
# - Finds the location of a certain record using either index or label for iloc and loc respectivel.

# %%
df.loc["Pikachu"] # uses a hashable label
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
df.iloc[30]# uses the index
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %% [markdown]
# - you can feed it a list of indexes or labels same as before

# %%
eeveelutions = ["Sylveon", "Umbreon", "Espeon", "Vaporeon", "Jolteon", "Flareon", "Leafeon", "Glaceon"]

df.loc[eeveelutions]
# Out:
#             #    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Sylveon   700     Fairy    NaN    525   95      65       65      110      130
# Umbreon   197      Dark    NaN    525   95      65      110       60      130
# Espeon    196   Psychic    NaN    525   65      65       60      130       95
# Vaporeon  134     Water    NaN    525  130      65       60      110       95
# Jolteon   135  Electric    NaN    525   65      65       60      110       95
# Flareon   136      Fire    NaN    525   65     130       60       95      110
# Leafeon   470     Grass    NaN    525   65     110      130       60       65
# Glaceon   471       Ice    NaN    525   65      60      110      130       95
#
#           Speed  Generation  Legendary
# Name
# Sylveon      60           6      False
# Umbreon      65           2      False
# Espeon      110           2      False
# Vaporeon     65           1      False
# Jolteon     130           1      False
# Flareon      65           1      False
# Leafeon      95           4      False
# Glaceon      65           4      False

# %%
eeveelutions_indices = [df.index.get_loc(name) for name in ["Sylveon", "Umbreon", "Espeon", "Vaporeon", "Jolteon", "Flareon", "Leafeon", "Glaceon"]]
print(eeveelutions_indices)
df.iloc[eeveelutions_indices]
# Out:
# [770, 212, 211, 145, 146, 147, 521, 522]
#             #    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Sylveon   700     Fairy    NaN    525   95      65       65      110      130
# Umbreon   197      Dark    NaN    525   95      65      110       60      130
# Espeon    196   Psychic    NaN    525   65      65       60      130       95
# Vaporeon  134     Water    NaN    525  130      65       60      110       95
# Jolteon   135  Electric    NaN    525   65      65       60      110       95
# Flareon   136      Fire    NaN    525   65     130       60       95      110
# Leafeon   470     Grass    NaN    525   65     110      130       60       65
# Glaceon   471       Ice    NaN    525   65      60      110      130       95
#
#           Speed  Generation  Legendary
# Name
# Sylveon      60           6      False
# Umbreon      65           2      False
# Espeon      110           2      False
# Vaporeon     65           1      False
# Jolteon     130           1      False
# Flareon      65           1      False
# Leafeon      95           4      False
# Glaceon      65           4      False

# %% [markdown]
# - loc allows you to slice as well

# %%
df.loc["Vaporeon": "Sylveon":2,["HP","Attack"]]
# Out:
#              HP  Attack
# Name
# Vaporeon    130      65
# Flareon      65     130
# Omanyte      35      40
# Kabuto       30      80
# Aerodactyl   80     105
# ...         ...     ...
# Dragalge     65      75
# Clawitzer    71      73
# Heliolisk    62      55
# Tyrantrum    82     121
# Aurorus     123      77
#
# [313 rows x 2 columns]

# %% [markdown]
# - **Slicing Columns:** loc and iloc also provides the means to slice columns

# %%
df.loc[:,"Attack":]
# Out:
#                        Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Name
# Bulbasaur                  49       49       65       65     45           1
# Ivysaur                    62       63       80       80     60           1
# Venusaur                   82       83      100      100     80           1
# VenusaurMega Venusaur     100      123      122      120     80           1
# Charmander                 52       43       60       50     65           1
# ...                       ...      ...      ...      ...    ...         ...
# Diancie                   100      150      100      150     50           6
# DiancieMega Diancie       160      110      160      110    110           6
# HoopaHoopa Confined       110       60      150      130     70           6
# HoopaHoopa Unbound        160       60      170      130     80           6
# Volcanion                 110      120      130       90     70           6
#
#                        Legendary
# Name
# Bulbasaur                  False
# Ivysaur                    False
# Venusaur                   False
# VenusaurMega Venusaur      False
# Charmander                 False
# ...                          ...
# Diancie                     True
# DiancieMega Diancie         True
# HoopaHoopa Confined         True
# HoopaHoopa Unbound          True
# Volcanion                   True
#
# [800 rows x 7 columns]

# %%
df.iloc[:,5:]
# Out:
#                        Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Name
# Bulbasaur                  49       49       65       65     45           1
# Ivysaur                    62       63       80       80     60           1
# Venusaur                   82       83      100      100     80           1
# VenusaurMega Venusaur     100      123      122      120     80           1
# Charmander                 52       43       60       50     65           1
# ...                       ...      ...      ...      ...    ...         ...
# Diancie                   100      150      100      150     50           6
# DiancieMega Diancie       160      110      160      110    110           6
# HoopaHoopa Confined       110       60      150      130     70           6
# HoopaHoopa Unbound        160       60      170      130     80           6
# Volcanion                 110      120      130       90     70           6
#
#                        Legendary
# Name
# Bulbasaur                  False
# Ivysaur                    False
# Venusaur                   False
# VenusaurMega Venusaur      False
# Charmander                 False
# ...                          ...
# Diancie                     True
# DiancieMega Diancie         True
# HoopaHoopa Confined         True
# HoopaHoopa Unbound          True
# Volcanion                   True
#
# [800 rows x 7 columns]

# %% [markdown]
# - **Conditional Slicing** : you can send a boolean mask through loc.

# %%
df.loc[df["Attack"] > 50]
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# Charmeleon               5     Fire     NaN    405  58      64       58
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Ivysaur                     80       80     60           1      False
# Venusaur                   100      100     80           1      False
# VenusaurMega Venusaur      122      120     80           1      False
# Charmander                  60       50     65           1      False
# Charmeleon                  80       65     80           1      False
# ...                        ...      ...    ...         ...        ...
# Diancie                    100      150     50           6       True
# DiancieMega Diancie        160      110    110           6       True
# HoopaHoopa Confined        150      130     70           6       True
# HoopaHoopa Unbound         170      130     80           6       True
# Volcanion                  130       90     70           6       True
#
# [630 rows x 12 columns]

# %% [markdown]
# ## **Subsetting & Appending to a DataFrame**

# %% [markdown]
# - **Subsetting Data:** Subsetting data means selecting specific rows and columns from a DataFrame based on certain conditions or criteria.

# %%
powerful_pokemon = df.loc[df["Total"] > 450]
powerful_pokemon
# Out:
#                              #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Venusaur                     3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur        3    Grass  Poison    625  80     100      123
# Charizard                    6     Fire  Flying    534  78      84       78
# CharizardMega Charizard X    6     Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y    6     Fire  Flying    634  78     104       78
# ...                        ...      ...     ...    ...  ..     ...      ...
# Diancie                    719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie        719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined        720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound         720  Psychic    Dark    680  80     160       60
# Volcanion                  721     Fire   Water    600  80     110      120
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Venusaur                       100      100     80           1      False
# VenusaurMega Venusaur          122      120     80           1      False
# Charizard                      109       85    100           1      False
# CharizardMega Charizard X      130       85    100           1      False
# CharizardMega Charizard Y      159      115    100           1      False
# ...                            ...      ...    ...         ...        ...
# Diancie                        100      150     50           6       True
# DiancieMega Diancie            160      110    110           6       True
# HoopaHoopa Confined            150      130     70           6       True
# HoopaHoopa Unbound             170      130     80           6       True
# Volcanion                      130       90     70           6       True
#
# [396 rows x 12 columns]

# %%
powerful_pokemon = df.query("Total > 450")
powerful_pokemon
# Out:
#                              #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Venusaur                     3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur        3    Grass  Poison    625  80     100      123
# Charizard                    6     Fire  Flying    534  78      84       78
# CharizardMega Charizard X    6     Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y    6     Fire  Flying    634  78     104       78
# ...                        ...      ...     ...    ...  ..     ...      ...
# Diancie                    719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie        719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined        720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound         720  Psychic    Dark    680  80     160       60
# Volcanion                  721     Fire   Water    600  80     110      120
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Venusaur                       100      100     80           1      False
# VenusaurMega Venusaur          122      120     80           1      False
# Charizard                      109       85    100           1      False
# CharizardMega Charizard X      130       85    100           1      False
# CharizardMega Charizard Y      159      115    100           1      False
# ...                            ...      ...    ...         ...        ...
# Diancie                        100      150     50           6       True
# DiancieMega Diancie            160      110    110           6       True
# HoopaHoopa Confined            150      130     70           6       True
# HoopaHoopa Unbound             170      130     80           6       True
# Volcanion                      130       90     70           6       True
#
# [396 rows x 12 columns]

# %% [markdown]
# - **Appending New Column:** Adding new columns means introducing new data fields to the DataFrame.

# %%
gen_to_region = {
    1: "Kanto",
    2: "Johto",
    3: "Hoenn",
    4: "Sinnoh",
    5: "Unova",
    6: "Kalos",
    7: "Alola",
    8: "Galar"
}

df["Region"] = df["Generation"].apply(lambda x: gen_to_region[x])
df.sample(10)
# Out:
#                         Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Cloyster                 Water       Ice    525  50      95      180       85
# Mime Jr.               Psychic     Fairy    310  20      25       45       70
# Turtwig                  Grass     Grass    318  55      68       64       45
# Shellos                  Water     Water    325  76      48       48       57
# Porygon-Z               Normal    Normal    535  85      80       70      135
# KeldeoOrdinary Forme     Water  Fighting    580  91      72       90      129
# Palpitoad                Water    Ground    384  75      65       55       65
# Azelf                  Psychic   Psychic    580  75     125       70      125
# Cubone                  Ground    Ground    320  50      50       95       40
# Meditite              Fighting   Psychic    280  30      40       55       40
#
#                       Sp. Def  Speed  Generation  Legendary  Region
# Name
# Cloyster                   45     70           1      False   Kanto
# Mime Jr.                   90     60           4      False  Sinnoh
# Turtwig                    55     31           4      False  Sinnoh
# Shellos                    62     34           4      False  Sinnoh
# Porygon-Z                  75     90           4      False  Sinnoh
# KeldeoOrdinary Forme       90    108           5      False   Unova
# Palpitoad                  55     69           5      False   Unova
# Azelf                      70    115           4       True  Sinnoh
# Cubone                     50     35           1      False   Kanto
# Meditite                   55     60           3      False   Hoenn

# %% [markdown]
# - **Dropping Columns:** Dropping columns means removing specific columns from the DataFrame.

# %%
df = df.drop('Region', axis=1)
df.sample(10)

# df = df[df.columns[:-1]]
# df.head()
# Out:
#               #    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Lillipup    506    Normal       NaN    275   45      60       45       25
# Goldeen     118     Water       NaN    320   45      67       60       35
# Kangaskhan  115    Normal       NaN    490  105      95       80       40
# Florges     671     Fairy       NaN    552   78      65       68      112
# Jumpluff    189     Grass    Flying    460   75      55       70       55
# Hitmontop   237  Fighting       NaN    455   50      95       95       35
# Stoutland   508    Normal       NaN    500   85     110       90       45
# Infernape   392      Fire  Fighting    534   76     104       71      104
# Chimchar    390      Fire       NaN    309   44      58       44       58
# Skrelp      690    Poison     Water    320   50      60       60       60
#
#             Sp. Def  Speed  Generation  Legendary
# Name
# Lillipup         45     55           5      False
# Goldeen          50     63           1      False
# Kangaskhan       80     90           1      False
# Florges         154     75           6      False
# Jumpluff         95    110           2      False
# Hitmontop       110     70           2      False
# Stoutland        90     80           5      False
# Infernape        71    108           4      False
# Chimchar         44     61           4      False
# Skrelp           60     30           6      False

# %% [markdown]
# - **Adding Row:** Dropping columns means removing specific columns from the DataFrame.

# %%
corviknight = {
    'Name' : 'Corviknight',
    '#' : 823,
    'Type 1': 'Flying',
    'Type 2': 'Steel',
    'HP': 98,
    'Attack': 87,
    'Defense': 105,
    'Sp. Atk': 53,
    'Sp. Def': 85,
    'Speed': 67,
    'Total': 495,
    'Generation': 8,
    'Legendary': False
}

# You can add this record to your DataFrame using:
# df = df.append(pd.DataFrame(corviknight,index=[0]).set_index('Name'))
# pd.concat([df.loc[:],pd.DataFrame(corviknight,index=[0]).set_index('Name')])
df.loc["Corviknight"] = {
    '#' : 823,
    'Type 1': 'Flying',
    'Type 2': 'Steel',
    'HP': 98,
    'Attack': 87,
    'Defense': 105,
    'Sp. Atk': 53,
    'Sp. Def': 85,
    'Speed': 67,
    'Total': 495,
    'Generation': 8,
    'Legendary': False
}
df.tail()
# Out:
#                        #   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# DiancieMega Diancie  719     Rock  Fairy    700  50     160      110      160
# HoopaHoopa Confined  720  Psychic  Ghost    600  80     110       60      150
# HoopaHoopa Unbound   720  Psychic   Dark    680  80     160       60      170
# Volcanion            721     Fire  Water    600  80     110      120      130
# Corviknight          823   Flying  Steel    495  98      87      105       53
#
#                      Sp. Def  Speed  Generation  Legendary
# Name
# DiancieMega Diancie      110    110           6       True
# HoopaHoopa Confined      130     70           6       True
# HoopaHoopa Unbound       130     80           6       True
# Volcanion                 90     70           6       True
# Corviknight               85     67           8      False

# %% [markdown]
# - **Removing a row Row:** Removing

# %% [markdown]
# - **Dropping Row:** Dropping columns means removing specific columns from the DataFrame.

# %%
df = df[df.index != 'Corviknight']
df.tail()
# Out:
#                        #   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
#
# Psychic   98.403509  86.280702   81.491228    3.385965   0.245614
# Rock      63.340909  75.477273   55.909091    3.454545   0.090909
# Steel     67.518519  80.629630   55.259259    3.851852   0.148148
# Water     74.812500  70.517857   65.964286    2.857143   0.035714

# %%
df.groupby(['Type 1', 'Type 2']).mean()
# Out:
#                           #       Total         HP      Attack     Defense  \
# Type 1 Type 2
# Bug    Electric  595.500000  395.500000  60.000000   62.000000   55.000000
#        Fighting  214.000000  550.000000  80.000000  155.000000   95.000000
#        Fire      636.500000  455.000000  70.000000   72.500000   60.000000
#        Flying    286.285714  419.500000  63.000000   70.142857   61.571429
#        Ghost     292.000000  236.000000   1.000000   90.000000   45.000000
# ...                     ...         ...        ...         ...         ...
# Water  Ice       103.000000  511.666667  90.000000   83.333333  113.333333
#        Poison    118.666667  426.666667  61.666667   68.333333   58.333333
#        Psychic   111.800000  481.000000  87.000000   73.000000  104.000000
#        Rock      430.000000  428.750000  70.750000   82.750000  112.750000
#        Steel     395.000000  530.000000  84.000000   86.000000   88.000000
#
#                     Sp. Atk     Sp. Def      Speed  Generation  Legendary
# Type 1 Type 2
# Bug    Electric   77.000000   55.000000  86.500000    5.000000        0.0
#        Fighting   40.000000  100.000000  80.000000    2.000000        0.0
#        Fire       92.500000   80.000000  80.000000    5.000000        0.0
#        Flying     72.857143   69.071429  82.857143    2.857143        0.0
#        Ghost      30.000000   30.000000  40.000000    3.000000        0.0
# ...                     ...         ...        ...         ...        ...
# Water  Ice        80.000000   78.333333  66.666667    1.000000        0.0
#        Poison     61.666667   91.666667  85.000000    1.333333        0.0
#        Psychic    94.000000   79.000000  44.000000    1.200000        0.0
#        Rock       61.500000   65.000000  36.000000    3.750000        0.0
#        Steel     111.000000  101.000000  60.000000    4.000000        0.0
#
# [136 rows x 10 columns]

# %% [markdown]
# ## Cleaning Data
#
# - Changing the Naming of Mega Pokemon

# %%
## The index of Mega Pokemons contained extra and unneeded text. Removed all the text before "Mega"
df.index = df.index.str.replace(".*(?=Mega)", "")
df.head(10)
# Out:
# <ipython-input-459-6b24d8d4f765>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace(".*(?=Mega)", "")
#                   # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur         1  Grass  Poison    318  45      49       49       65
# Ivysaur           2  Grass  Poison    405  60      62       63       80
# Venusaur          3  Grass  Poison    525  80      82       83      100
# Mega Venusaur     3  Grass  Poison    625  80     100      123      122
# Charmander        4   Fire     NaN    309  39      52       43       60
# Charmeleon        5   Fire     NaN    405  58      64       58       80
# Charizard         6   Fire  Flying    534  78      84       78      109
# Mega Charizard X  6   Fire  Dragon    634  78     130      111      130
# Mega Charizard Y  6   Fire  Flying    634  78     104       78      159
# Squirtle          7  Water     NaN    314  44      48       65       50
#
#                   Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur              65     45           1      False
# Ivysaur                80     60           1      False
# Venusaur              100     80           1      False
# Mega Venusaur         120     80           1      False
# Charmander             50     65           1      False
# Charmeleon             65     80           1      False
# Charizard              85    100           1      False
# Mega Charizard X       85    100           1      False
# Mega Charizard Y      115    100           1      False
# Squirtle               64     43           1      False

# %% [markdown]
# - Dealing with Null data in Type2

# %%
#some values in TYPE2 are empty and thus they have to be filled or deleted
df['Type 2'].fillna(df['Type 1'], inplace=True) #fill NaN values in Type2 with corresponding values of Type
df.head(10)
# Out:
#                   # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur         1  Grass  Poison    318  45      49       49       65
# Ivysaur           2  Grass  Poison    405  60      62       63       80
# Venusaur          3  Grass  Poison    525  80      82       83      100
# Mega Venusaur     3  Grass  Poison    625  80     100      123      122
# Charmander        4   Fire    Fire    309  39      52       43       60
# Charmeleon        5   Fire    Fire    405  58      64       58       80
# Charizard         6   Fire  Flying    534  78      84       78      109
# Mega Charizard X  6   Fire  Dragon    634  78     130      111      130
# Mega Charizard Y  6   Fire  Flying    634  78     104       78      159
# Squirtle          7  Water   Water    314  44      48       65       50
#
#                   Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur              65     45           1      False
# Ivysaur                80     60           1      False
# Venusaur              100     80           1      False
# Mega Venusaur         120     80           1      False
# Charmander             50     65           1      False
# Charmeleon             65     80           1      False
# Charizard              85    100           1      False
# Mega Charizard X       85    100           1      False
# Mega Charizard Y      115    100           1      False
# Squirtle               64     43           1      False

# %% [markdown]
# - Removing the original entry number.

# %%
df = df.drop("#",axis=1)

# %% [markdown]
# - subset of Non Mega Pokemon / Non Primal

# %%
df_filtered = df.loc[~df.index.str.contains('Mega','Primal')]

# %% [markdown]
# Q3. Identify Pokémon with the Highest Individual Stats
#
# - Objective:
#   - Determine which Pokémon has the highest value in each individual stat in a given Pokémon dataset.
#
# - Expected Output:
#   - highest_stats should be a dictionary with keys like "Max HP", "Max Attack", etc., and their corresponding Pokémon names as values.

# %%
highest_stats = {"Max " + name: df[name].idxmax() for name in df.columns[2:-2]}
highest_stats
# Out:
# {'Max Total': 'Mega Mewtwo X',
#  'Max HP': 'Blissey',
#  'Max Attack': 'Mega Mewtwo X',
#  'Max Defense': 'Mega Steelix',
#  'Max Sp. Atk': 'Mega Mewtwo Y',
#  'Max Sp. Def': 'Shuckle',
#  'Max Speed': 'DeoxysSpeed Forme'}

# %% [markdown]
# ## Correlation between the attributes ?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

plt.figure(figsize=(10,6)) #manage the size of the plot
sns.heatmap(df.corr(),annot=True) #df.corr() makes a correlation matrix and sns.heatmap is used to show the correlations heatmap
plt.show()
# Out:
# <ipython-input-464-fe67b9012f6d>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True) #df.corr() makes a correlation matrix and sns.heatmap is used to show the correlations heatmap

# %% [markdown]
# ## What is the distribution of Pokemon Types?

# %%
types = df['Type 1'].unique()
counts = [len(df.query('`Type 1` == @typ or `Type 2` == @typ')) for typ in types ]

colors = sns.color_palette('pastel')

plt.axis('equal')
plt.title("Percentage of Different Types of Pokemon")
plt.pie(counts, labels = types, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ## Attack by Type

# %%
plt.subplots(figsize = (17,7.5))
plt.title('Attack by Type1')
sns.violinplot(x = "Type 1", y = "Attack",data = df_filtered)
plt.ylim(0,230)
plt.show()

# %% [markdown]
# # Strongest Region of Pokemon

# %%
plt.subplots(figsize = (15,5))
plt.title('Strongest Genaration')
sns.violinplot(x = "Region", y = "Total",data = df)
plt.show()
